# %%
#Задание 1. Даны 2 строки: long_phrase и short_phrase. Напишите код, который проверяет действительно ли длинная фраза long_phrase длиннее короткой short_phrase. И выводит True или False в зависимости от результата сравнения.

long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
print(len(long_phrase)>len(short_phrase))
# Out:
# True

# %%
#Задание 2. Дано значение объема файла в байтах (в мегабайте 2^20 байт). Напишите перевод этого значения в мегабайты в формате: "Объем файла равен 213.68Mb".



print('Объем файла равен ', 213.68*(2**20), 'байт')

# %%
user_input = input('Введите месяц рождения ')
user_input2 = int(input('Введите дату рождения '))
if user_input == 'январь':
    zodiac = 'Козерог' if (user_input2 < 21) else 'Водолей'
elif user_input == 'февраль':
    zodiac = 'Водолей' if (user_input2 < 21) else 'Рыбы'
elif user_input == 'март':
    zodiac = 'Рыбы' if (user_input2 < 21) else 'Овен'
elif user_input == 'апрель':
    zodiac = 'Овен' if (user_input2 < 21) else 'Телец'
elif user_input == 'май':
    zodiac = 'Телец' if (user_input2 < 21) else 'Близнецы'
elif user_input == 'июнь':
    zodiac = 'Близнецы' if (user_input2 < 21) else 'Рак'
elif user_input == 'июль':
    zodiac = 'Рак' if (user_input2 < 21) else 'Лев'
elif user_input == 'август':
    zodiac = 'Лев' if (user_input2 < 21) else 'Дева'
elif user_input == 'сентябрь':
    zodiac = 'Дева' if (user_input2 < 21) else 'Весы'
elif user_input == 'октябрь':
    zodiac = 'Весы' if (user_input2 < 21) else 'Скорпион'
elif user_input == 'ноябрь':
    zodiac = 'Скорпион' if (user_input2 < 21) else 'Стрелец'
elif user_input == 'декабрь':
    zodiac = 'Стрелец' if (user_input2 < 21) else 'Козерог'

print(zodiac)
# Out:
# Введите месяц рождения январь
# Введите дату рождения 14
# Козерог

# %%
salary = int(input ('Введите заработанную плату в месяц: '))
mortage = int(input ('Введите сколько процентов от ЗП уходит на ипотеку: '))
life = int(input ('Введите сколько процентов от ЗП уходит "на жизнь": '))
bonus = int(input ('Введите сколько раз приходит премия в год: '))
                   
mortagewaste= salary/100*mortage*12                  
bonussavings = salary*bonus/2

#также к сбережениям отнесла то, что не тратится на жизнь и ипотеку
savingsafterlifeandmortage = (salary*12) - ((salary/100*life*12)+(salary/100*mortage*12))
allsavings = savingsafterlifeandmortage + savingsafterlifeandmortage


print('Вывод: На ипотеку было потрачено: ', mortagewaste, ' рублей. Было накоплено: ', allsavings, ' рублей.')
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов от ЗП уходит на ипотеку: 30
# Введите сколько процентов от ЗП уходит "на жизнь": 50
# Введите сколько раз приходит премия в год: 2
# Вывод: На ипотеку было потрачено:  360000.0  рублей. Было накоплено:  480000.0  рублей.
